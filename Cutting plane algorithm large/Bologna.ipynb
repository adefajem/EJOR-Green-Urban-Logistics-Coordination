# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
import math
import pickle
import gurobipy as gp
from gurobipy import GRB
import CuttingPlaneFunctions as cuttingPlane
from time import perf_counter as pc
import sys
# np.set_printoptions(threshold=sys.maxsize)
pd.set_option('display.max_rows', None)
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2481345
# Academic license 2481345 - for non-commercial use only - registered to da___@skema.edu

# %% [markdown]
# ## 1. Bilevel and NonComp

# %%
# Run CP on 
city_name = 'bologna'
all_instances = [
[[1,1], [1,1,0,0,0], [1,1,0,0,0], 100],
[[1,1], [1,1,0,0,0], [1,1,1,0,0], 100],
[[1,1], [1,1,1,0,0], [1,1,0,0,0], 100],
[[1,1], [1,1,1,0,0], [1,1,1,0,0], 100]
]

for instance in all_instances:
    cuttingPlane.run_instance(city_name, instance)
