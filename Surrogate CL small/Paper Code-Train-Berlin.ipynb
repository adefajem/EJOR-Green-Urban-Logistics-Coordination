# %% [markdown]
# # 4a. Constraint Learning - Training

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
import math
import pickle
import gurobipy as gp
from gurobipy import GRB
import CuttingPlaneFunctions as cuttingPlane
import MultiObjectiveFunctions as multiObj
import ConstraintLearningFunctions as constrLearn
from time import perf_counter as pc
import sys
# np.set_printoptions(threshold=sys.maxsize)
pd.set_option('display.max_rows', None)

# %%
city_name = 'berlin'
distance_and_times_filename = "instances/"+city_name+"_distances_times_2_3_3_50.pickle"
locations_and_windows_filename = "instances/"+city_name+"_locations_windows_2_3_3_50.pickle"
city_network_filename = "instances/"+city_name+"_2_3_3_50.xlsx"

# %%
num_to_generate_FM = 10000
num_to_generate_LM = 6000 
constrLearn.network_training(city_name, city_network_filename, distance_and_times_filename, 
                             locations_and_windows_filename, num_to_generate_FM, num_to_generate_LM)
# Out:
# Generating training data points...
# FM data generation...
# i= 0
# i= 1
# i= 2
# i= 3
# i= 4
# LM data generation...
# i= 0
# i= 1
